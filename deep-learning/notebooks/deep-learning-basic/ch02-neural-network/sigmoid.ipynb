# %% [markdown]
# 활성화 함수 2) 시그모이드 함수 구현하기

# %%
# coding: utf-8
import numpy as np
import matplotlib.pylab as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x)) # 시그모이드 함수

X = np.arange(-5.0, 5.0, 0.1)
y = sigmoid(X)
plt.plot(X, y)
plt.ylim(-0.1, 1.1) #y축 범위 지정
plt.show()
