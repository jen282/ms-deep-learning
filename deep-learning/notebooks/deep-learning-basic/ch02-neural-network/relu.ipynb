# %% [markdown]
# 활성화 함수 3) Relu 함수 구현하기

# %%
# coding: utf-8
import numpy as np
import matplotlib.pylab as plt

def relu(x):
    return np.maximum(0, x) # x >0인 경우만 x를 그대로 출력

X = np.arange(-5.0, 5.0, 0.1)
y = relu(X)
plt.plot(X, y)
plt.ylim(-1.0, 5.5) #y축 범위 지정
plt.show()
